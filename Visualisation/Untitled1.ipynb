# %%
from ESPRIT_numpy import *
import pickle
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display, Audio
import librosa.feature as ft
import wave
import struct
import librosa
import time
import librosa.display
from os import listdir
from os.path import isfile, join
import scipy.io
from mpl_toolkits import mplot3d
import pickle
from scipy.io.wavfile import write
# %matplotlib widget
monRepertoire = 'C:/Users/Ulysse/Desktop/ATIAM/PAM/Mesures/Mesures_2023.01.27_LAM_normalise_hr/bruit/Medium_1/Corde_Acier/C_1_P_2.wav'
Fe = 22050
data_seul,_ = librosa.load(monRepertoire,sr=Fe)

# %%
data_seul
# Out:
# array([ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#        -5.6504068e-05, -4.3897504e-05, -3.7838210e-05], dtype=float32)

# %%
plt.figure()
plt.plot(data_seul)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
display(Audio(data_seul, rate=Fe))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fft = np.fft.fft(data_seul)
n = data_seul.size
freq = np.fft.fftfreq(n, d=1/Fe)
plt.figure()
plt.plot(freq,np.abs(data_seul))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
