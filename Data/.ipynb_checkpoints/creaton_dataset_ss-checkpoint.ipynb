# %%
from création_data import param_Dataset
import fonction_model as f
from IPython.display import display, Audio
from scipy.io.wavfile import write
import pickle

# %%
Fe = 2**14

# %%
Fichier = "../../Dataset/Test vico/"
N_sample, param_dataset, xinB = param_Dataset(N_sample=200,
                                             article_C = True,
                                             acier_1C = False,
                                             acier_2C = False, 
                                             medium_1T = False, 
                                             medium_2T = True, 
                                             metal_T = False,
                                             plexi_T = False)

# %%
N_sample=20
for i in range(N_sample):
    T,rho_l,L,E_corde,I,h,E_nu,rhoT,Lx,Ly = param_dataset[0]
    pos_chev_Nt = f.Main_ss(T,rho_l,L,E_corde,I,h,E_nu,rhoT,Lx,Ly,xinB,Fe)
    write(Fichier + str(i) + '.wav',rate=Fe ,data = pos_chev_Nt / max(abs(pos_chev_Nt)))

# %%
from IPython.display import display, Audio

display(Audio(pos_chev_Nt, rate=Fe))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
