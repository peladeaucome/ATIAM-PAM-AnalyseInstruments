# %%
from création_data import param_Dataset
import fonction_model as f
from IPython.display import display, Audio
from scipy.io.wavfile import write
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib widget

# %%
Fe = [2**14,2**15,2**16,2**17,2**18]

# %%
]
Fichier = "Data_set_acc_1/plexi/"
N_sample, param_dataset, xinB = param_Dataset(N_sample=10,

                                             article_C = False,
                                             acier_1C = True, # corde de ré
                                             acier_2C = False, # corde de la

                                             medium_1T = True, 
                                             medium_2T = False, 
                                             metal_T = False,
                                             plexi_T = False)
T,rho_l,L,B,h,E_nu,rhoT,Lx,Ly = param_dataset[0]

# %%
Q_1,Q_pos_1, F_1,phiB_NxNy_NmB= f.Main(T,rho_l,L,B,h,E_nu,rhoT,Lx,Ly,xinB,Fe[0])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# /Users/armandschwarz/Documents/GitHub/ATIAM-PAM-AnalyseInstruments/Data/fonction_model.py:293: RuntimeWarning: invalid value encountered in matmul
#   q_dd_temp[:,i+1] = W @  q_pour_f[:,i+1]
# /Users/armandschwarz/Documents/GitHub/ATIAM-PAM-AnalyseInstruments/Data/fonction_model.py:300: RuntimeWarning: invalid value encountered in matmul
#   F_c = Z @ q_pour_f
# /Users/armandschwarz/Documents/GitHub/ATIAM-PAM-AnalyseInstruments/Data/fonction_model.py:306: RuntimeWarning: overflow encountered in matmul
#   FS_NxS_Nt = phiS_Nx_NmS[-1,:] @ FS

# %%
Q_2,Q_pos_2, F_2,phiB_NxNy_NmB= f.Main(T,rho_l,L,B,h,E_nu,rhoT,Lx,Ly,xinB,Fe[1])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# /Users/armandschwarz/Documents/GitHub/ATIAM-PAM-AnalyseInstruments/Data/fonction_model.py:293: RuntimeWarning: invalid value encountered in matmul
#   q_dd_temp[:,i+1] = W @  q_pour_f[:,i+1]
# /Users/armandschwarz/Documents/GitHub/ATIAM-PAM-AnalyseInstruments/Data/fonction_model.py:295: RuntimeWarning: invalid value encountered in add
#   q_d_temp = q_d_temp + 0.5 * h * (q_dd_temp[:,i] + q_dd_temp[:,i+1])
# /Users/armandschwarz/Documents/GitHub/ATIAM-PAM-AnalyseInstruments/Data/fonction_model.py:300: RuntimeWarning: invalid value encountered in matmul
#   F_c = Z @ q_pour_f
# /Users/armandschwarz/Documents/GitHub/ATIAM-PAM-AnalyseInstruments/Data/fonction_model.py:306: RuntimeWarning: overflow encountered in matmul
#   FS_NxS_Nt = phiS_Nx_NmS[-1,:] @ FS
# ...

# %%
Q_3,Q_pos_3, F_3,phiB_NxNy_NmB= f.Main(T,rho_l,L,B,h,E_nu,rhoT,Lx,Ly,xinB,Fe[2])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Q_4,Q_pos_4, F_4,phiB_NxNy_NmB= f.Main(T,rho_l,L,B,h,E_nu,rhoT,Lx,Ly,xinB,Fe[3])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Q_5,Q_pos_5, F_5,phiB_NxNy_NmB= f.Main(T,rho_l,L,B,h,E_nu,rhoT,Lx,Ly,xinB,Fe[4])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from scipy.signal import resample

Q_2_r = 
Q_3_r =
