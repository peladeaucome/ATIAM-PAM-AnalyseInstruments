# %% [markdown]
# ### Ce notebook récupère les données de simulation du modèle depuis "launch_simu_ss.py" pour en faire des visualisations.

# %%
from guitare_config import *
from simu_config import *
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append("../")

# %matplotlib widget

#plt.rc('text', usetex=True)
#plt.rc('font', family='serif')
plt.rcParams["figure.figsize"] = (12,4)
# Out:
# Fréquence du dernier mode de corde calculé : 11636 Hz
# Fréquence du dernier mode de plaque calculé : 655 Hz
# Fréquence d'échantillonage : 16000 Hz
# Temps d'acquisition : 3 s

# %%
from launch_simu_ss import *

# %%
from launch_simu_odeint import *
# Out:
# Fréquence du dernier mode de corde calculé : 11636 Hz
# Fréquence du dernier mode de plaque calculé : 655 Hz
# Fréquence d'échantillonage : 16000 Hz
# Temps d'acquisition : 3 s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/bigand/Desktop_bis/M2 - Codes/PAM/ATIAM-PAM-AnalyseInstruments/Guitar_model/vico_modphy/visu_vico.ipynb Cellule 4 in <module>
# ----> <a href='vscode-notebook-cell:/Users/bigand/Desktop_bis/M2%20-%20Codes/PAM/ATIAM-PAM-AnalyseInstruments/Guitar_model/vico_modphy/visu_vico.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> from launch_simu_odeint import *
#
# File ~/Desktop_bis/M2 - Codes/PAM/ATIAM-PAM-AnalyseInstruments/Guitar_model/vico_modphy/launch_simu_odeint.py:40, in <module>
#      37     # print(q_point_point.shape)
#      38     return Q_point
# ---> 40 sol = odeint(derivative, y0 = np.zeros(2*(NmB+NmS)), t=t)
#
# File /usr/local/lib/python3.9/site-packages/scipy/integrate/_odepack_py.py:242, in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     240 t = copy(t)
#     241 y0 = copy(y0)
# --> 242 output = _odepack.odeint(func, y0, t, args, Dfun, col_deriv, ml, mu,
#     243                          full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     244                          ixpr, mxstep, mxhnil, mxordn, mxords,
#     245                          int(bool(tfirst)))
#     246 if output[-1] < 0:
#     247     warning_msg = _msgs[output[-1]] + " Run with full_output = 1 to get quantitative information."
#
# File ~/Desktop_bis/M2 - Codes/PAM/ATIAM-PAM-AnalyseInstruments/Guitar_model/vico_modphy/launch_simu_odeint.py:30, in derivative(q, time)
#      28 t_idx = mm.find_nearest_index(t, time)
#      29 q_point = q[NmB+NmS:]
# ---> 30 q_point_point = A @ q + W @ np.block([
#      31     [MSinv],
#      32     [np.zeros((NmB,NmS))]
#      33 ]) @ U[:,t_idx]
#      35 Q_point = np.concatenate([q_point, q_point_point])
#      37 # print(q_point_point.shape)
#
# File <__array_function__ internals>:5, in block(*args, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/numpy/core/shape_base.py:849, in block(arrays)
#     847     return _block_slicing(arrays, list_ndim, result_ndim)
#     848 else:
# --> 849     return _block_concatenate(arrays, list_ndim, result_ndim)
#
# File /usr/local/lib/python3.9/site-packages/numpy/core/shape_base.py:893, in _block_concatenate(arrays, list_ndim, result_ndim)
#     892 def _block_concatenate(arrays, list_ndim, result_ndim):
# --> 893     result = _block(arrays, list_ndim, result_ndim)
#     894     if list_ndim == 0:
#     895         # Catch an edge case where _block returns a view because
#     896         # `arrays` is a single numpy array and not a list of numpy arrays.
#     897         # This might copy scalars or lists twice, but this isn't a likely
#     898         # usecase for those interested in performance
#     899         result = result.copy()
#
# File /usr/local/lib/python3.9/site-packages/numpy/core/shape_base.py:660, in _block(arrays, max_depth, result_ndim, depth)
#     651 """
#     652 Internal implementation of block based on repeated concatenation.
#     653 `arrays` is the argument passed to
#    (...)
#     657 for details).
#     658 """
#     659 if depth < max_depth:
# --> 660     arrs = [_block(arr, max_depth, result_ndim, depth+1)
#     661             for arr in arrays]
#     662     return _concatenate(arrs, axis=-(max_depth-depth))
#     663 else:
#     664     # We've 'bottomed out' - arrays is either a scalar or an array
#     665     # type(arrays) is not list
#
# File /usr/local/lib/python3.9/site-packages/numpy/core/shape_base.py:660, in <listcomp>(.0)
#     651 """
#     652 Internal implementation of block based on repeated concatenation.
#     653 `arrays` is the argument passed to
#    (...)
#     657 for details).
#     658 """
#     659 if depth < max_depth:
# --> 660     arrs = [_block(arr, max_depth, result_ndim, depth+1)
#     661             for arr in arrays]
#     662     return _concatenate(arrs, axis=-(max_depth-depth))
#     663 else:
#     664     # We've 'bottomed out' - arrays is either a scalar or an array
#     665     # type(arrays) is not list
#
# File /usr/local/lib/python3.9/site-packages/numpy/core/shape_base.py:662, in _block(arrays, max_depth, result_ndim, depth)
#     659 if depth < max_depth:
#     660     arrs = [_block(arr, max_depth, result_ndim, depth+1)
#     661             for arr in arrays]
# --> 662     return _concatenate(arrs, axis=-(max_depth-depth))
#     663 else:
#     664     # We've 'bottomed out' - arrays is either a scalar or an array
#     665     # type(arrays) is not list
#     666     return _atleast_nd(arrays, result_ndim)
#
# KeyboardInterrupt:

# %%
A.shape
# Out:
# (232, 232)

# %%
B.shape
# Out:
# (232, 100)

# %% [markdown]
# # Simulation
#
# On compare aussi la méthode de vico (_ss) et la méthode de l'article (_ar). La méthode ss est plus robuste car elle fonctionne quelque soit Fe, mais moins rapide. La méthode de l'article fonctionne pour Fe=44100 mais pas diverge à bas Fe.

# %%
#Choix méthode
# method = "article"
method = "ss"
# method = "compare"

# %%
if method == "ss" : 
    import launch_simu_ss

    Q = launch_simu_ss.Q
    #Mouvement de la corde
    QS = Q[:NmS,:]
    QB = Q[NmS:,:]

    #Passage dans les coordonnées cartésiennes
    simuS_NxS_Nt = phiS_Nx_NmS @ QS
    simuB_NxNy_Nt = phiB_NxNy_NmB @ QB

elif method == "article" :
    import launch_simu_article

    Q = launch_simu_article.Q
    #Mouvement de la corde
    QS = Q[:NmS,:]
    QB = Q[NmS:,:]

    #Passage dans les coordonnées cartésiennes
    simuS_NxS_Nt = phiS_Nx_NmS @ QS
    simuB_NxNy_Nt = phiB_NxNy_NmB @ QB

elif method == "compare" :
    ...
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/bigand/Desktop_bis/M2 - Codes/PAM/ATIAM-PAM-AnalyseInstruments/Guitar_model/vico_modphy/visu_vico.ipynb Cellule 5 in <module>
#       <a href='vscode-notebook-cell:/Users/bigand/Desktop_bis/M2%20-%20Codes/PAM/ATIAM-PAM-AnalyseInstruments/Guitar_model/vico_modphy/visu_vico.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> if method == "ss" :
# ----> <a href='vscode-notebook-cell:/Users/bigand/Desktop_bis/M2%20-%20Codes/PAM/ATIAM-PAM-AnalyseInstruments/Guitar_model/vico_modphy/visu_vico.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a>     import launch_simu_ss
#       <a href='vscode-notebook-cell:/Users/bigand/Desktop_bis/M2%20-%20Codes/PAM/ATIAM-PAM-AnalyseInstruments/Guitar_model/vico_modphy/visu_vico.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a>     Q = launch_simu_ss.Q
#       <a href='vscode-notebook-cell:/Users/bigand/Desktop_bis/M2%20-%20Codes/PAM/ATIAM-PAM-AnalyseInstruments/Guitar_model/vico_modphy/visu_vico.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a>     #Mouvement de la corde
#
# File ~/Desktop_bis/M2 - Codes/PAM/ATIAM-PAM-AnalyseInstruments/Guitar_model/vico_modphy/launch_simu_ss.py:14, in <module>
#       1 """
#       2 Ce code permet de configurer l'espace d'état du modèle et de lancer une simulation temporelle.
#       3
#    (...)
#      10 - Vecteur Q de dimension (NmS+NmB, Nt) : représente l'évolution des participations modales au cours du temps de la position de la corde sur les NmS premières coordonnées, et de la table sur les NmB dernières coordonnées.
#      11 """
#      13 from guitare_config import *
# ---> 14 from UK_parameters import *
#      15 from simu_config import t, FextS_NxS_Nt
#      17 import control #C'est un module à télécharger qui permet de simuler des espaces d'état : https://python-control.readthedocs.io/en/0.9.1/
#
# File ~/Desktop_bis/M2 - Codes/PAM/ATIAM-PAM-AnalyseInstruments/Guitar_model/vico_modphy/UK_parameters.py:31, in <module>
#      24 phiBS = phiB_NxNy_NmB
#      26 Aa1 = np.block([
#      27                 [phiSB.T, np.zeros(NmB)],
#      28                 [phiSF.T, np.zeros(NmB)]
#      29 ])
# ---> 31 Aa2 = np.block([
#      32                 [phiSB.T, -phiBS],
#      33                 [phiSF.T, np.zeros(NmB)]
#      34 ])
#      36 # Choix concernant le mouvement de la table au point de couplage
#      37 Aa = Aa2
#
# File <__array_function__ internals>:5, in block(*args, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/numpy/core/shape_base.py:849, in block(arrays)
#     847     return _block_slicing(arrays, list_ndim, result_ndim)
#     848 else:
# --> 849     return _block_concatenate(arrays, list_ndim, result_ndim)
#
# File /usr/local/lib/python3.9/site-packages/numpy/core/shape_base.py:893, in _block_concatenate(arrays, list_ndim, result_ndim)
#     892 def _block_concatenate(arrays, list_ndim, result_ndim):
# --> 893     result = _block(arrays, list_ndim, result_ndim)
#     894     if list_ndim == 0:
#     895         # Catch an edge case where _block returns a view because
#     896         # `arrays` is a single numpy array and not a list of numpy arrays.
#     897         # This might copy scalars or lists twice, but this isn't a likely
#     898         # usecase for those interested in performance
#     899         result = result.copy()
#
# File /usr/local/lib/python3.9/site-packages/numpy/core/shape_base.py:660, in _block(arrays, max_depth, result_ndim, depth)
#     651 """
#     652 Internal implementation of block based on repeated concatenation.
#     653 `arrays` is the argument passed to
#    (...)
#     657 for details).
#     658 """
#     659 if depth < max_depth:
# --> 660     arrs = [_block(arr, max_depth, result_ndim, depth+1)
#     661             for arr in arrays]
#     662     return _concatenate(arrs, axis=-(max_depth-depth))
#     663 else:
#     664     # We've 'bottomed out' - arrays is either a scalar or an array
#     665     # type(arrays) is not list
#
# File /usr/local/lib/python3.9/site-packages/numpy/core/shape_base.py:660, in <listcomp>(.0)
#     651 """
#     652 Internal implementation of block based on repeated concatenation.
#     653 `arrays` is the argument passed to
#    (...)
#     657 for details).
#     658 """
#     659 if depth < max_depth:
# --> 660     arrs = [_block(arr, max_depth, result_ndim, depth+1)
#     661             for arr in arrays]
#     662     return _concatenate(arrs, axis=-(max_depth-depth))
#     663 else:
#     664     # We've 'bottomed out' - arrays is either a scalar or an array
#     665     # type(arrays) is not list
#
# File /usr/local/lib/python3.9/site-packages/numpy/core/shape_base.py:662, in _block(arrays, max_depth, result_ndim, depth)
#     659 if depth < max_depth:
#     660     arrs = [_block(arr, max_depth, result_ndim, depth+1)
#     661             for arr in arrays]
# --> 662     return _concatenate(arrs, axis=-(max_depth-depth))
#     663 else:
#     664     # We've 'bottomed out' - arrays is either a scalar or an array
#     665     # type(arrays) is not list
#     666     return _atleast_nd(arrays, result_ndim)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 1 and the array at index 1 has size 1040

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.plot(t, simuS_NxS_Nt[750,:])
ax1.set_title(rf"Evolution temporelle du point $x$={xS[750]:.2f} de la corde, méthode : {method}")
# if both :  ##si on a choisi les deux méthodes on plote la dif des deux 
#     ax1.plot(t, simuS_NxS_Nt_ss[NxS//2,:] - simuS_NxS_Nt_ar[NxS//2,:],label="")
#     ax1.set_title(rf"Evolution temporelle du point $x$={xS[NxS//2]:.2f} de la corde, différence des deux méthodes")

ax1.plot()
ax1.grid()
ax1.set_xlabel("Temps (s)")
ax1.set_ylabel("Déplacement (m)")
fig.tight_layout()

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

img = ax1.imshow(np.abs(simuB_NxNy_Nt[:,int(1.5*Fe)]).reshape((Ny,Nx)),
    #extent=[x[0], x[-1] , y[0], y[-1]] ,
    cmap="jet",
    interpolation = "none",
    # aspect="auto" ,
    origin="lower")

from UK_parameters import xc_idx, yc_idx

ax1.scatter(xc_idx,yc_idx)

fig.colorbar(img,ax=ax1)
ax1.set_xlabel("Longueur $x$ (m)")
ax1.set_ylabel(r"Largeur $y$ (m)")
ax1.set_title(rf"Profil vibratoire de la plaque à $t$={t[int(1.5*Fe)]:.1f} s, méthode : {method}")

fig.tight_layout()

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x[int(24.5/40*Nx)]
# Out:
# 0.24

# %% [markdown]
# # Ecoute

# %%
from IPython.display import display, Audio

display(Audio(simuS_NxS_Nt[500,:], rate=Fe))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Exportation des GIFs

# %%
#GIF CORDE
fe_anim = 15     #Hz

N_interval_anim = int(Fe/fe_anim)   #Nombre de points entre 0 et 1/fe_anim secondes

Ntanim = int(Nt/N_interval_anim)    #Nombre de points total de l'échantillonage visuel en fe_anim FPS
rms_Ntanim_NxS = np.zeros((Ntanim,NxS))
t_anim = np.zeros(Ntanim)
for i in range(Ntanim) :
    # rms_Ntanim_Nx[i,:] = np.sqrt(np.sum(np.square(xcorde_Nx_Nt[:,i*N_interval_anim:i*N_interval_anim+N_interval_anim-1]),axis=1))
    rms_Ntanim_NxS[i,:] = simuS_NxS_Nt[:,i*N_interval_anim]
    t_anim[i] = t[i*N_interval_anim]

rms_Nx_Ntanim = rms_Ntanim_NxS.T

fig = plt.figure(figsize=(13,6))
ax1 = fig.add_subplot(111)

line, = ax1.plot(xS,rms_Nx_Ntanim[:,0],label="")
ax1.grid()
# ax1.legend()
ax1.set_xlabel("$x$")
ax1.set_ylabel("$y(x,t)$")
ax1.set_title(f"temps t={t_anim[0]}s")
ax1.set_ylim(np.min(rms_Nx_Ntanim),np.max(rms_Nx_Ntanim))

def init() :
    line.set_ydata(rms_Nx_Ntanim[:,0])
    line.set_xlim()
    ax1.set_title(f"temps t={t_anim[0]}s")
    return line,

def update(t_idx) :
    line.set_ydata(rms_Nx_Ntanim[:,t_idx])
    ax1.set_title(f"temps t={t_anim[t_idx]:.0f} s")
    return line,

import matplotlib.animation as animation

myAnimation = animation.FuncAnimation(fig, update, frames=Ntanim, interval=1/fe_anim, blit=True, repeat=False)
print("Done ✅")

myAnimation.save("figures/gif_corde.gif", writer='PillowWriter', fps=fe_anim)

# %%
#GIF PLAQUE
fe_anim = 50     #Hz

N_interval_anim = int(Fe/fe_anim)   #Nombre de points entre 0 et 1/fe_anim secondes

Ntanim = int(5*Fe/N_interval_anim)    #Nombre de points total de l'échantillonage visuel en fe_anim FPS
rms_Ntanim_NxNy = np.zeros((Ntanim,Nx*Ny))
t_anim = np.zeros(Ntanim)
for i in range(Ntanim) :
    # rms_Ntanim_NxNy[i,:] = simuB_NxNy_Nt[:,i*N_interval_anim]
    rms_Ntanim_NxNy[i,:] = np.sqrt(np.sum(np.square(simuB_NxNy_Nt[:,i*N_interval_anim:i*N_interval_anim+N_interval_anim-1]),axis=1))
    t_anim[i] = t[i*N_interval_anim]

rms_NxNy_Ntanim = rms_Ntanim_NxNy.T

fig = plt.figure(figsize=(13,6))
ax1 = fig.add_subplot(111)

img = ax1.imshow(np.abs(rms_NxNy_Ntanim[:,0]).reshape((Nx,Ny)),
    extent=[x[0], x[-1] , y[0], y[-1]] ,
    cmap="jet" ,
    interpolation = "bilinear",
    aspect="auto" ,
    origin="lower")

fig.colorbar(img,ax=ax1)
ax1.set_xlabel("")
ax1.set_ylabel(r"")
ax1.set_title(r"")


def init() :
    img.set_data(np.abs(rms_NxNy_Ntanim[:,0]).reshape((Nx,Ny)))
    ax1.set_title(f"temps t={t_anim[0]}s")
    return [img]

def update(t_idx) :
    img.set_data(np.abs(rms_NxNy_Ntanim[:,t_idx]).reshape((Nx,Ny)))
    ax1.set_title(f"temps t={t_anim[t_idx]:.0f} s")
    img.set_clim([np.min(np.abs(rms_NxNy_Ntanim[:,:])),np.max(np.abs(rms_NxNy_Ntanim[:,:]))])
    return [img]

import matplotlib.animation as animation

myAnimation = animation.FuncAnimation(fig, update, frames=Ntanim, interval=1/fe_anim, blit=True, repeat=False)
print("Done ✅")

myAnimation.save("figures/gif_plaque.gif", writer='PillowWriter', fps=fe_anim/2)

# %%
dx*1e3
